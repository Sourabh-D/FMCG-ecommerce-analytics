# %% [markdown]
# # E-commerce FMCG Data Analytics Project
# Complete workflow: data loading, EDA, churn model, SQL queries, insights.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Load datasets
customers = pd.read_excel('powerbi_data_model.xlsx', sheet_name='Customers')
products = pd.read_excel('powerbi_data_model.xlsx', sheet_name='Products')
orders = pd.read_excel('powerbi_data_model.xlsx', sheet_name='Orders')
marketing = pd.read_excel('powerbi_data_model.xlsx', sheet_name='Marketing')
